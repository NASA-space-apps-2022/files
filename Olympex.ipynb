# %% [markdown]
# # Olymic Mountains Precipitations
# ## OLYPEX NASA

# %% [markdown]
# ## Source:
# [RAINFALL STATISTICS-OLYMPEX NASA](https://search.earthdata.nasa.gov/search?q=gpmrgnaolyx&lat=-0.0703125&long=0.0703125)
#
# [OUR GITHUB](https://github.com/NASA-space-apps-2022/files)

# %% [markdown]
# # Code

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataa1 = pd.read_csv('rain 2015_1.csv', index_col=False)
data1 = pd.DataFrame(dataa1)

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3847 entries, 0 to 3846
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Year        3847 non-null   object
#  1   Mon         3846 non-null   float64
#  2   Day         3846 non-null   float64
#  3   Jday        3846 non-null   float64
#  4   Hr          3846 non-null   float64
#  5   Min         3846 non-null   float64
#  6   Sec         3846 non-null   float64
#  7   Rain[mm]    3846 non-null   float64
#  8   Month+year  3847 non-null   object
#  9   Lat         3846 non-null   float64
#  10  Lon         3846 non-null   float64
# dtypes: float64(9), object(2)
# memory usage: 330.7+ KB

# %%
#datta1=data1
#cleanup_categorical = {"Mon":     {0:" ", 1: "January", 2: "February", 3: "March", 4: "April", 5: "May", 6: "June", 7: "July", 8: "August", 9: "September", 10: "October", 11: "November", 12: "December"}
 #               }

# %%
#data1=datta1.replace(cleanup_categorical)
data1.head()
# Out:
#    Year  Mon  Day  Jday    Hr   Min  Rain[mm/h] Month+year       Lat  \
# 0  2015  1.0  1.0   1.0  17.0  25.0        3.05     1/2015  47.35902
# 1  2015  1.0  1.0   1.0  17.0  26.0        3.05     1/2015  47.35902
# 2  2015  1.0  1.0   1.0  17.0  27.0        3.05     1/2015  47.35902
# 3  2015  1.0  1.0   1.0  17.0  28.0        3.05     1/2015  47.35902
# 4  2015  1.0  1.0   1.0  17.0  29.0        3.05     1/2015  47.35902
#
#          Lon
# 0 -123.99142
# 1 -123.99142
# 2 -123.99142
# 3 -123.99142
# 4 -123.99142

# %%
 dataa3 = pd.read_csv('rain 2016_1.csv', index_col=False)
data3 = pd.DataFrame(dataa3)

# %%
#datta3=data3
#cleanup_categorical = {"Mon":     {0:" ", 1: "January", 2: "February", 3: "March", 4: "April", 5: "May", 6: "June", 7: "July", 8: "August", 9: "September", 10: "October", 11: "November", 12: "December"}
 #               }

# %%
#data3=datta3.replace(cleanup_categorical)
data3.head()
# Out:
#    Year  Mon  Day  Jday  Hr  Min  Rain[mm/h]       Lat        Lon
# 0  2016    1    5     5   6   48        3.05  47.35996 -123.99303
# 1  2016    1    5     5   6   49        3.05  47.35996 -123.99303
# 2  2016    1    5     5   6   50        3.05  47.35996 -123.99303
# 3  2016    1    5     5   6   51        3.05  47.35996 -123.99303
# 4  2016    1    5     5   6   52        3.05  47.35996 -123.99303

# %%
gb1=data1.groupby(["Year","Mon"])["Rain[mm/h]"].mean();
rain2015=pd.DataFrame(gb1)
rain2015np=np.array(rain2015)
gb1=data1.groupby(["Year","Mon"], as_index=False)["Rain[mm/h]"].mean();
rain2015=pd.DataFrame(gb1)

# %%
rain2015_1=rain2015.assign(Rain_in_inches=rain2015np*60/25.4)
rain2015_1
# Out:
#    Year   Mon  Rain[mm/h]  Rain_in_inches
# 0  2015   1.0    6.608941       15.611671
# 1  2015   2.0    3.417623        8.073126
# 2  2015   3.0    2.967336        7.009455
# 3  2015   4.0    3.210884        7.584765
# 4  2015   5.0    3.381813        7.988533
# 5  2015   6.0    2.185333        5.162205
# 6  2015   7.0    3.050000        7.204724
# 7  2015   9.0    2.287407        5.403324
# 8  2015  10.0    4.731224       11.176119

# %%
rain2015_1.plot(x="Mon", y=["Rain_in_inches"])
plt.show()

# %%
gb3=data3.groupby(["Year","Mon"])["Rain[mm/h]"].mean();
rain2016=pd.DataFrame(gb3)
rain2016np=np.array(rain2016)
gb3=data3.groupby(["Year","Mon"], as_index=False)["Rain[mm/h]"].mean();
rain2016=pd.DataFrame(gb3)

# %%
rain2016_1=rain2016.assign(Rain_in_inches=rain2016np*60/25.4)
rain2016_1
# Out:
#    Year  Mon  Rain[mm/h]  Rain_in_inches
# 0  2016    1    3.621987        8.555876
# 1  2016    2    2.886955        6.819579
# 2  2016    3    3.433315        8.110192
# 3  2016    4    3.262381        7.706412
# 4  2016    5    2.540100        6.000236

# %%
rain2016_1.plot(x="Mon", y=["Rain_in_inches"])
plt.show()
